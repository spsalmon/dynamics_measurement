# %%
import numpy as np
import matplotlib.pyplot as plt
from cellpose import models, io
from cellpose.io import imread
from tqdm import tqdm
io.logger_setup()

model = models.CellposeModel(gpu=False, pretrained_model="/mnt/towbin.data/shared/spsalmon/towbinlab_segmentation_database/cellpose/models/emr1_60x")

# list of files
# PUT PATH TO YOUR FILES HERE!
file = "/mnt/towbin.data/shared/nschoonjans/20260227_Ziva_60X_405_EV-eat-6RNAi/raw_stacks/Time00052_Point0052_ChannelDIA,DIA_Seq4888.ome.tiff"

image = imread(file)[:, 1]

image = image[np.newaxis, :, :]

masks, flows, styles = model.eval(plane)
# Out:
# 2026-03-10 16:22:04,316 [INFO] WRITING LOG OUTPUT TO /home/spsalmon/.cellpose/run.log
# 2026-03-10 16:22:04,317 [INFO]
# cellpose version: 	4.0.9
# platform:       	linux
# python version: 	3.12.13
# torch version:  	2.10.0+cu128
# 2026-03-10 16:22:04,319 [INFO] >>>> using CPU
# 2026-03-10 16:22:04,320 [INFO] >>>> using CPU
# 2026-03-10 16:22:06,520 [INFO] >>>> loading model /mnt/towbin.data/shared/spsalmon/towbinlab_segmentation_database/cellpose/models/emr1_60x
# 2026-03-10 16:22:07,580 [INFO] reading tiff with 50 planes
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# (1200, 1200)
#   0%|          | 0/25 [03:35<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 19
#      17 print(plane.shape)
#      18 plane = plane[np.newaxis, :, :]
# ---> 19 masks, flows, styles = model.eval(plane)
#      20 plt.imshow(masks)
#      21 plt.show()
#
# ...
